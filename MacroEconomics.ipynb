# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import ipywidgets as widgets

# %%
df = pd.read_csv('core_system/GDP.csv')

# %%
new_columns = ['Date'] + list(df.columns[1:])

# %%
df.columns = new_columns

# %%
countries = df.columns[1:]

# %%
sel = widgets.SelectMultiple(
    options=countries,
    value=['Belarus'],
    #rows=10,
    description='Fruits',
    disabled=False
)
sel
# Out:
# SelectMultiple(description='Fruits', index=(22,), options=('Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andor…

# %%
select_countries = list(sel.value)

# %%
selected_df = df[['Date'] + select_countries]

# %%
df_melted = selected_df.melt(id_vars=['Date'], var_name='Country', value_name='GDP')

# Создание интерактивного графика с помощью Plotly Express
fig = px.line(df_melted, x='Date', y='GDP', color='Country', title='GDP by Country')

# Отображение графика
fig.show()
# Out:
# <div>                            <div id="afa4ed06-dfc6-4f08-b802-e563722923a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afa4ed06-dfc6-4f08-b802-e563722923a1")) {                    Plotly.newPlot(                        "afa4ed06-dfc6-4f08-b802-e563722923a1",                        [{"hovertemplate":"Country=Belarus<br>Date=%{x}<br>GDP=%{y}<extra></extra>","legendgroup":"Belarus","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Belarus","orientation":"v","showlegend":true,"x":[2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,2001,2000,1999,1998,1997,1996,1995,1994,1993,1992,1991,1990,1989,1988,1987,1986,1985,1984,1983,1982,1981,1980,1979,1978,1977,1976,1975,1974,1973,1972,1971,1970,1969,1968,1967,1966,1965,1964,1963,1962],"xaxis":"x","y":[59948354831.6356,58600611434.1156,59013474192.6442,58198692497.6768,56421856742.7841,55028435771.7374,56454734396.5842,58702799524.0454,57706562174.7975,57133246703.6914,56185324133.9697,53317530166.8315,49460470690.6153,49361749506.6609,44792876368.1538,41245740029.6776,37496129067.9992,34274340535.4692,30753180384.6838,28729692799.2932,27349821166.1531,26115771070.4161,24684092836.7343,23872430402.7966,22022539015.0,19768885050.6478,19230432058.6858,21462535897.5156,24306383742.7746,26305610635.692,29099127258.7491,29452556633.7413,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=France<br>Date=%{x}<br>GDP=%{y}<extra></extra>","legendgroup":"France","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"France","orientation":"v","showlegend":true,"x":[2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,2001,2000,1999,1998,1997,1996,1995,1994,1993,1992,1991,1990,1989,1988,1987,1986,1985,1984,1983,1982,1981,1980,1979,1978,1977,1976,1975,1974,1973,1972,1971,1970,1969,1968,1967,1966,1965,1964,1963,1962],"xaxis":"x","y":[2577595870536.12,2413104454442.24,2616812485718.01,2569458097202.24,2522413420333.78,2465909086487.94,2439188643162.5,2412341398046.84,2389493466482.81,2375801091055.54,2368384855035.17,2317567536989.14,2273251909006.52,2340501872979.04,2334550031985.42,2279283420792.28,2224791087607.91,2188393293109.35,2128171303325.76,2110796058518.4,2087096421588.52,2046499571261.18,1969233367607.74,1904087419529.25,1838123429815.53,1796159810500.7,1771133801947.67,1734591250411.78,1694626166709.98,1705347110174.84,1678502109603.77,1661090955411.7,1613901522615.43,1546714398124.5,1476673666392.57,1439787739478.76,1406904493488.19,1384438090121.85,1363794045035.68,1347078619777.78,1314153853595.82,1300253881649.64,1280045228283.46,1236161624649.22,1188862221373.28,1149055358647.74,1101083792491.43,1111755362632.65,1065911376205.15,1002318472123.85,959052047239.664,910636112294.556,858210764567.69,801246352672.883,766806695424.451,730840925163.32,694373557438.493,662181550405.328,620879995295.485,584447414017.366],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Micronesia, Fed. Sts.<br>Date=%{x}<br>GDP=%{y}<extra></extra>","legendgroup":"Micronesia, Fed. Sts.","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Micronesia, Fed. Sts.","orientation":"v","showlegend":true,"x":[2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,2001,2000,1999,1998,1997,1996,1995,1994,1993,1992,1991,1990,1989,1988,1987,1986,1985,1984,1983,1982,1981,1980,1979,1978,1977,1976,1975,1974,1973,1972,1971,1970,1969,1968,1967,1966,1965,1964,1963,1962],"xaxis":" ...
