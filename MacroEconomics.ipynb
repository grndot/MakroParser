# %%
import pandas as pd
import plotly as plt
import i

# %%
# %pwd
# Out:
# '/home/losandtok/PycharmProjects/MakroParser'

# %%
df = pd.read_csv('core_system/GDP.csv')

# %%
df.tail(5)
# Out:
#     Unnamed: 0  Aruba  Afghanistan  Angola  Albania  Andorra  \
# 55        1966    NaN          NaN     NaN      NaN      NaN
# 56        1965    NaN          NaN     NaN      NaN      NaN
# 57        1964    NaN          NaN     NaN      NaN      NaN
# 58        1963    NaN          NaN     NaN      NaN      NaN
# 59        1962    NaN          NaN     NaN      NaN      NaN
#
#     United Arab Emirates     Argentina  Armenia  American Samoa  ...  \
# 55                   NaN  1.805568e+11      NaN             NaN  ...
# 56                   NaN  1.817559e+11      NaN             NaN  ...
# 57                   NaN  1.643817e+11      NaN             NaN  ...
# 58                   NaN  1.492611e+11      NaN             NaN  ...
# 59                   NaN  1.576283e+11      NaN             NaN  ...
#
#     British Virgin Islands  Virgin Islands (U.S.)  Vietnam  Vanuatu  Samoa  \
# 55                     NaN                    NaN      NaN      NaN    NaN
# ...
